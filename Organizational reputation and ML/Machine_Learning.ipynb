# %% [markdown]
# # Organisational Reputation and ML

# %% [markdown]
# ## Constants and preparations

# %% [markdown]
# ### Constants

# %%
import os

LABELS_JSON_FILENAME = "labels2.json"
# DOCUMENTS_DOCX_FOLDER = 'Training Set for Hugo'
DOCUMENTS_DOCX_FOLDER = '/home/hugo/MEGA/work/Agency_Classification/Teaching_sample_2019_34_agencies/Teaching sample 2019 34 agencies'
TEXTFILES_FOLDER = os.path.join(os.getcwd(), 'documents_txt')
RAW_DATA_JSON_FILE = 'raw_data.json'
PREPROCESSED_JSON_FILE = 'raw_data.json'

# %% [markdown]
# ### Preparations

# %%
if not os.path.exists(TEXTFILES_FOLDER):
    os.makedirs(TEXTFILES_FOLDER)

# %% [markdown]
# ## Read the labels

# %%
# !ls
# Out:
#  agency_counts.csv			 label_agency_heatmap.png
#  agency_label_crosstab.csv		 label_counts.csv
#  agency_label_crosstab_percentages.csv	 labels2.json
#  all_data.json				 labels.csv
#  all_data_no_predictions.csv		 labels.json
#  analyze.ipynb				 Machine_Learning.ipynb
# 'Coding for Hugo.xlsx'			 make_new_labels_file.ipynb
#  confidence_pivot.csv			 pycaret.ipynb
#  confidence_pivot_only_agencies.csv	 raw_data.json
#  confidence_pivot_only_labels.csv	 regulatory_vs_non_regulatory.csv
#  data_with_labels.csv			 regulatory_vs_non_regulatory.png
#  documents_txt				 results
#  dpc2vec.ipynb				 SVM_trained.pk
#  evaluation_pivot.csv			'Training Set for Hugo'
#  evaluation_pivot_only_agencies.csv	 vectorizer.pk
#  evaluation_pivot_only_labels.csv	 year_label_heatmap.png
#  experiments_results

# %%
from csv import DictReader

def read_labels(filename:str = "labels.csv"):
    data = []

    with open(filename, 'rt') as f:
        reader = DictReader(f, delimiter='\t')
        for line in reader:
            line['Dimension 1st'] = line['Dimension 1']
            line['Dimension 2nd'] = line['Dimension 2']
            
            del line['Dimension 1']
            del line['Dimension 2']
            
            data.append(line)
            
    print(f"{len(data)} lines loaded")
    return data
            
def process_labels(labels):
    for line in labels:
        if not line['Document'].endswith(".docx"):
            line["Document"] = line["Document"].strip() + ".docx"
        
        line['Dimension 1st'] = str(int(line['Dimension 1st']))
        line['Dimension 2nd'] = str(int(line['Dimension 2nd']))

# %%
label_names = {
    "1": "Technical",
    "2": "Performative",
    "3": "Procedural",
    "4": "Moral"
}

# %%
import os

labels_file = "labels_FINAL.csv"
labels_folder = "/home/hugo/MEGA/work/Agency_Classification"
labels_file_path = os.path.join(labels_folder, labels_file)
assert os.path.exists(labels_file_path)

# %%
import json

labels = read_labels(labels_file_path)
labels
# Out:
# 1302 lines loaded
# [OrderedDict([('Document', 'ACER 2019 1.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 2.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 3.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 4.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 5.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 6.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 7.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 8.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 9.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 10.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 11.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 12.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 13.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 14.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 15.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 16.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 17.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 18.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 19.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 20.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 21.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 22.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 23.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 24.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 25.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 26.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 27.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 28.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 29.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 30.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 31.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 32.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 33.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 34.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 35.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 36.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 37.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 38.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 39.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 40.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 41.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 42.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 43.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 44.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ACER 2019 45.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 46.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 47.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ACER 2019 48.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ACER 2019 49.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 1.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'BEREC 2019 2.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 3.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'BEREC 2019 4.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 5.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'BEREC 2019 6.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 7.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'BEREC 2019 8.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 9.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 10.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 11.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'BEREC 2019 12.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'BEREC 2019 13.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 14.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 15.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'BEREC 2019 16.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 17.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 18.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'BEREC 2019 19.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'BEREC 2019 20.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'CdT 2019 1'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'CdT 2019 2'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'CdT 2019 3'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'CdT 2019 4'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'CdT 2019 5'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'CdT 2019 6'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'CdT 2019 7'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 1.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 2.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 3.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cedefop 2019 4.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cedefop 2019 5.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cedefop 2019 6.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 7.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 8.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 9.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cedefop 2019 10.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 11.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 12.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 13.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 14.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 15.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 16.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 17.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 18.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 19.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 20.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 21.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 22.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 23.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 24.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 25.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 26.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cedefop 2019 27.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 29.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 30.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 31.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 32.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cedefop 2019 33.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 34.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 35.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 36.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 38.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 39.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 40.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 42.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cedefop 2019 43.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 44.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 45.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 46.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 47.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 48.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cedefop 2019 49.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 50.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 63.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 64.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 72.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 74.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 76.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 77.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 78.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 91.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 104.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 110.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 123.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cedefop 2019 129.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 143.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 144.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 150.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 152.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cedefop 2019 154.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 160.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cedefop 2019 165.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'Cepol 2019 1.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 5.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 6.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cepol 2019 7.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 8.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cepol 2019 9.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cepol 2019 10.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cepol 2019 11.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cepol 2019 12.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 13.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 14.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 16.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cepol 2019 17.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 18.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 19.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 27.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 55.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'Cepol 2019 70.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'Cepol 2019 74.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'Cepol 2019 86.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'CVPO 2019 1.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'CVPO 2019 2.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'CVPO 2019 3.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'CVPO 2019 4.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'CVPO 2019 5.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'CVPO 2019 6.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'CVPO 2019 7.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'CVPO 2019 8.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'CVPO 2019 9.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'CVPO 2019 10.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'CVPO 2019 11.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'CVPO 2019 12.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 1.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 2.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 3.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 4.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 5.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 6.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 7.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 8.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 9.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 10.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 11.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 12.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 13.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 14.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 15.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 16.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 17.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 18.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 19.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 20.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 21.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 22.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 23.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 28.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 29.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 30.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 32.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 33.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 35.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 36.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 37.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 38.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 39.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 40.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 41.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EASA 2019 42.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EASA 2019 43.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 44.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 45.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EASA 2019 46.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 47.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EASA 2019 48.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 49.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 50.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 54.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 58.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASA 2019 60.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 64.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASA 2019 PR 1.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASA 2019 PR 3.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EASA 2019 PR 6.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 1.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 2.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 3.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 4.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 5.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 6.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 7.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 8.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 9.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 10.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 11.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 12.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 13.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 14.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 15.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 16.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 17.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 18.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 19.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EASO 2019 20.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 21.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 22.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 23.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 25.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 26.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 27.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EASO 2019 28.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 29.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 30.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 31.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 32.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 33.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 34.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 35.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EASO 2019 36.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 38.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EASO 2019 39.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EASO 2019 40.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EASO 2019 41.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 1.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 2.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 3.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 4.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 5.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 6.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 7.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 8.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 9.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 10.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 11.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 12.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 13.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EBA 2019 PR 14.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 15.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 16.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 17.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 18.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 19.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 20.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 21.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 22.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 23.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 24.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 25.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 26.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 27.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 28.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 29.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 30.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 31.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 32.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 33.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 34.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 35.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 36.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 37.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 38.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 39.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 40.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 41.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 42.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 43.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 44.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 45.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 46.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 47.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 48.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 49.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 50.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 51.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 52.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 56.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 57.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 58.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 59.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 60.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 61.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 63.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 64.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 65.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 67.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 70.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EBA 2019 PR 75.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 78.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 80.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'EBA 2019 PR 87.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 91.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 93.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 104.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 105.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 106.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 109.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 110.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 112.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 113.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 118.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EBA 2019 PR 120.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'EBA 2019 PR 125.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EBA 2019 PR 126.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ECDC 2019 1.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ECDC 2019 2.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'ECDC 2019 3.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 4.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 5.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 6.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 7.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 8.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 9.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 10.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'ECDC 2019 11.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 12.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'ECDC 2019 13.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 14.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 15.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 16.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 17.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 18.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'ECDC 2019 19.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 20.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 21.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'ECDC 2019 22.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 23.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ECDC 2019 24.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 25.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 26.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 27.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'ECDC 2019 28.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 29.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 30.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ECDC 2019 31.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ECDC 2019 32.docx'),
# ...
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 4.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 5.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 6.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 7.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 8.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 9.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 10.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 11.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 12.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 13.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 14.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 16.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'ESMA 2019 17.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 18.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 19.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 20.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 21.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 22.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 23.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 24.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 25.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 26.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 27.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 28.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 29.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 30.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '4')]),
#  OrderedDict([('Document', 'ESMA 2019 31.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 32.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 33.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 34.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 35.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 36.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 37.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 38.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 39.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 40.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 41.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 42.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 43.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 44.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 45.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 46.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 47.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 48.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 49.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 50.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 57.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 62.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 67.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 69.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 86.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 87.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 92.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 93.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 98.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 108.docx'),
#               ('Dimension 1st', '4'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 112.docx'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 121.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 126.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 127.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 129.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 140.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 141.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 142.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 143.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 144.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 145.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 146.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 147.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 148.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 149.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 150.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 155.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 157.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 158.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 162.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 164.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 165.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 166.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 172.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 178.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 185.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 186.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 187.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 190.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 192.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 196.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 197.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 198.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 199.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 202.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 208.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ESMA 2019 209.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 210.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 212.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 213.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 222.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 227.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 233.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 236.docx'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 239.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ESMA 2019 248.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ESMA 2019 256.docx'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ETF 2019 1'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 2'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 3'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 4'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ETF 2019 5'),
#               ('Dimension 1st', '1'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 6'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 7'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ETF 2019 8'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ETF 2019 9'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ETF 2019 10'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ETF 2019 11'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 12'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 13'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ETF 2019 14'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 15'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ETF 2019 16'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ETF 2019 17'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'ETF 2019 18'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '1')]),
#  OrderedDict([('Document', 'ETF 2019 19'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'ETF 2019 20'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EU-Lisa 2019 1'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  OrderedDict([('Document', 'EU-Lisa 2019 2'),
#               ('Dimension 1st', '2'),
#               ('Dimension 2nd', '2')]),
#  OrderedDict([('Document', 'EU-Lisa 2019 3'),
#               ('Dimension 1st', '3'),
#               ('Dimension 2nd', '3')]),
#  ...]

# %%
import json

labels = read_labels(labels_file_path)

process_labels(labels)
with open(LABELS_JSON_FILENAME, 'wt') as out:
    json.dump(labels, out)

    assert os.path.exists(LABELS_JSON_FILENAME), "The file must be created."
# !ls
# Out:
# 1302 lines loaded
#  agency_counts.csv			 label_agency_heatmap.png
#  agency_label_crosstab.csv		 label_counts.csv
#  agency_label_crosstab_percentages.csv	 labels2.json
#  all_data.json				 labels.csv
#  all_data_no_predictions.csv		 labels.json
#  analyze.ipynb				 Machine_Learning.ipynb
# 'Coding for Hugo.xlsx'			 make_new_labels_file.ipynb
#  confidence_pivot.csv			 pycaret.ipynb
#  confidence_pivot_only_agencies.csv	 raw_data.json
#  confidence_pivot_only_labels.csv	 regulatory_vs_non_regulatory.csv
#  data_with_labels.csv			 regulatory_vs_non_regulatory.png
#  documents_txt				 results
#  dpc2vec.ipynb				 SVM_trained.pk
#  evaluation_pivot.csv			'Training Set for Hugo'
#  evaluation_pivot_only_agencies.csv	 vectorizer.pk
#  evaluation_pivot_only_labels.csv	 year_label_heatmap.png
#  experiments_results

# %%
import json

with open(LABELS_JSON_FILENAME, 'rt') as f:
    labels = json.load(f)
    
print(len(labels))
print(labels[:5])
# Out:
# 1302
# [{'Document': 'ACER 2019 1.docx', 'Dimension 1st': '1', 'Dimension 2nd': '1'}, {'Document': 'ACER 2019 2.docx', 'Dimension 1st': '1', 'Dimension 2nd': '2'}, {'Document': 'ACER 2019 3.docx', 'Dimension 1st': '2', 'Dimension 2nd': '3'}, {'Document': 'ACER 2019 4.docx', 'Dimension 1st': '1', 'Dimension 2nd': '1'}, {'Document': 'ACER 2019 5.docx', 'Dimension 1st': '3', 'Dimension 2nd': '3'}]

# %%
for item in labels:
    if 'SBR' in item['Document']:
        print(item)
# Out:
# {'Document': 'SBR 2019 1.docx', 'Dimension 1st': '3', 'Dimension 2nd': '3', 'id': 'SBR 2019 1', 'text': 'Single Resolution Board extends prior permissions procedure\xa0\nThe Single Resolution Board’s procedure to assess applications to reduce eligible liabilities instruments under Article 78a of the Capital Requirements Regulation will remain in place until the relevant European Banking Authority’s Regulatory Technical Standards come into force.\xa0To continue performing market-making and other secondary market activities as of 1 January 2020, banks must obtain a prior permission.\xa0\nTo cover the period until the standards come into force, the SRB confirms and extends the\xa0\xa0in the CRR addendum to the SRB’s MREL policy:\nthe aggregate trading volume in these activities does not exceed 1% TREA on a consolidated basis at the level of the resolution group;\nany MREL shortfall, or increase thereof, resulting from these market-making activities is compensated with eligible liabilities instruments on a quarterly basis.\nBackground\nThe European Banking Authority (EBA) is mandated under Article 78a (3) CRR to draft Regulatory Technical Standards (RTS) specifying the process for prior permissions, including the time limits and information requirements. Until this Level 2 Regulation comes into application, the following provisional procedure applies:\nScope of instruments. At this stage, the SRB considers that the permission regime applies to eligible liabilities instruments as defined in Article 72b CRR.\nTime-limit for applications. Institutions shall transmit a complete application to the SRB at least four months in advance of the date where one of the actions listed in Article 78a CRR (hereafter: “Redemption”) is intended to be performed.\n', 'processed_text': 'single resolution board extends prior permission procedure single resolution board ’ procedure ass application reduce eligible liability instrument article capital requirement regulation remain place relevant european banking authority ’ regulatory technical standard come force continue performing marketmaking secondary market activity january bank must obtain prior permission cover period standard come force srb confirms extends crr addendum srb ’ mrel policy aggregate trading volume activity exceed trea consolidated basis level resolution group mrel shortfall increase thereof resulting marketmaking activity compensated eligible liability instrument quarterly basis background european banking authority mandated article crr draft regulatory technical standard rts specifying process prior permission including time limit information requirement level regulation come application following provisional procedure applies scope instrument stage srb considers permission regime applies eligible liability instrument defined article b crr timelimit application institution shall transmit complete application srb least four month advance date one action listed article crr hereafter “ redemption ” intended performed'}
# {'Document': 'SBR 2019 2.docx', 'Dimension 1st': '3', 'Dimension 2nd': '2', 'id': 'SBR 2019 2', 'text': 'SRB and European Commission sign Memorandum of Understanding\nThe Single Resolution Board and the European Commission have signed a\xa0\xa0in order to further strengthen their cooperation. The two authorities share the objectives of ensuring the orderly resolution of failing banks while protecting financial stability and ensuring that taxpayers are not first in line to bear costs.\nElke König, SRB Chair, and Valdis Dombrovskis, Vice-President of the European Commission, signed the document on 1 August 2019 and it is published today.\nThe MoU spells out the working methods between the SRB and the Commission in line with the Single Resolution Mechanism (SRM) legal framework. This includes cooperation on resolution, regulatory and communication matters. It does not extend to cooperation on European Commission decisions related to State aid in resolution, as provided for in Article 19 of the SRM.\n', 'processed_text': 'srb european commission sign memorandum understanding single resolution board european commission signed order strengthen cooperation two authority share objective ensuring orderly resolution failing bank protecting financial stability ensuring taxpayer first line bear cost elke könig srb chair valdis dombrovskis vicepresident european commission signed document august published today mou spell working method srb commission line single resolution mechanism srm legal framework includes cooperation resolution regulatory communication matter extend cooperation european commission decision related state aid resolution provided article srm'}
# {'Document': 'SBR 2019 3.docx', 'Dimension 1st': '3', 'Dimension 2nd': '2', 'id': 'SBR 2019 3', 'text': 'SRB statement on European Court judgments annulling 2016 ex-ante contributions decisions for three banks\nThe Single Resolution Board (SRB) takes note of yesterday’s judgments of the General Court of the European Union annulling the SRB’s decisions on the 2016 ex-ante contributions of Banco Cooperativo Español, Portigon, and Hypo Vorarlberg Bank to the Single Resolution Fund.\xa0\nThe judgments only relate to the ex-ante contributions of these three institutions for 2016. There will be no impact on the build-up of the Single Resolution Fund. The contributions of these entities represent a very small percentage of the overall ex-ante contributions collected from more than 3,700 institutions in 2016.\nIn the judgments, the Court identified certain flaws related to procedural elements of the decision-making process in 2016, when the SRB was in its start-up phase. It made no comment on the calculation methodology, nor on the validity of the legal framework for calculating the ex-ante contributions.\nThe SRB will carefully assess the content of the judgments in order to determine the next steps, which\xa0will be taken in cooperation with the relevant National Resolution Authorities (NRAs). The banks remain under the obligation to pay ex-ante contributions for 2016.\nAbout the Single Resolution Fund\nThe Single Resolution Fund (SRF) was established by Regulation (EU) No 806/2014 (SRM Regulation). The SRF may be used to ensure the efficient application of resolution tools and the exercise of the SRB’s resolution powers. The Fund\xa0is composed of contributions from credit institutions and certain investment firms in the 19 Banking Union Member States.\xa0It ensures that the financial industry, as a whole, finances the stabilisation of the financial system. The SRF is gradually being built up during the first eight years (2016-2023) and shall reach the target level of at least 1% of the amount of covered deposits of all credit institutions within the Banking Union by 31 December 2023.\nAbout ex-ante contributions\nContributions to the SRF are raised annually from institutions in scope in each of the 19 Banking Union Member States. The SRB cooperates with the NRAs to ensure the raising of all the contributions due by the institutions under its remit. In particular, the SRB is responsible for the calculation of\xa0ex-ante contributions. The NRAs are responsible for the collection of contributions and the transfer to the SRF.\n', 'processed_text': 'srb statement european court judgment annulling exante contribution decision three bank single resolution board srb take note yesterday ’ judgment general court european union annulling srb ’ decision exante contribution banco cooperativo español portigon hypo vorarlberg bank single resolution fund judgment relate exante contribution three institution impact buildup single resolution fund contribution entity represent small percentage overall exante contribution collected institution judgment court identified certain flaw related procedural element decisionmaking process srb startup phase made comment calculation methodology validity legal framework calculating exante contribution srb carefully ass content judgment order determine next step taken cooperation relevant national resolution authority nra bank remain obligation pay exante contribution single resolution fund single resolution fund srf established regulation eu srm regulation srf may used ensure efficient application resolution tool exercise srb ’ resolution power fund composed contribution credit institution certain investment firm banking union member state ensures financial industry whole finance stabilisation financial system srf gradually built first eight year shall reach target level least amount covered deposit credit institution within banking union december exante contribution contribution srf raised annually institution ...
# {'Document': 'SBR 2019 4.docx', 'Dimension 1st': '2', 'Dimension 2nd': '2', 'id': 'SBR 2019 4', 'text': 'Single Resolution Board Publishes 2020 Work Programme\nThe Single Resolution Board (SRB) has today published its 2020 Work Programme, setting out its priorities and core tasks for the year ahead. 2020 is the final year of the\xa0\xa0and will mark the fifth anniversary of the SRB taking on its full powers within the Single Resolution Mechanism.\nThe\xa0\xa0is an ambitious roadmap towards strengthening the resolvability of SRB entities and less significant institutions, fostering a robust resolution framework, carrying out effective crisis management, building up further the single resolution fund (from 33 billion in 2019 to around 41 billion next year) and establishing a lean and efficient organisation.\nA focus for the year ahead will be on ensuring that the SRB’s internal policies, resolution plans and minimum requirements for own funds and eligible liabilities (MREL) decisions reflect the requirements of the\xa0.\nThe SRB also expects banks to proactively work to make themselves resolvable, taking on board these new and existing requirements. The SRB’s ‘Expectations for Banks’ document, which was\xa0\xa0on 23 October 2019, sets out the general capabilities the SRB expects banks to demonstrate in order to show that they are resolvable.\nOther important priorities will be operationalising the political agreements on the backstop reached in 2019, as well as increasing preparedness for potential new Banking Union members with regard to SRF contributions. The year will also see the SRB operate at full staff capacity for the first time, with close to 400 colleagues on hand to deliver the SRB’s ambitious programme.\n“As we reach the end of this current multiannual programme, the next one is already being prepared. The 2021-2024 programme has particular salience considering the link with the end of the transition period of the SRF. The SRB will keep up the momentum towards resolvability and looks forward to continuing its close cooperation with the national resolution authorities, the European Central Bank and our wider stakeholder community,” said Dr Elke König, Chair of the SRB.\n\n', 'processed_text': 'single resolution board publishes work programme single resolution board srb today published work programme setting priority core task year ahead final year mark fifth anniversary srb taking full power within single resolution mechanism ambitious roadmap towards strengthening resolvability srb entity le significant institution fostering robust resolution framework carrying effective crisis management building single resolution fund billion around billion next year establishing lean efficient organisation focus year ahead ensuring srb ’ internal policy resolution plan minimum requirement fund eligible liability mrel decision reflect requirement srb also expects bank proactively work make resolvable taking board new existing requirement srb ’ ‘ expectation bank ’ document october set general capability srb expects bank demonstrate order show resolvable important priority operationalising political agreement backstop reached well increasing preparedness potential new banking union member regard srf contribution year also see srb operate full staff capacity first time close colleague hand deliver srb ’ ambitious programme “ reach end current multiannual programme next one already prepared programme particular salience considering link end transition period srf srb keep momentum towards resolvability look forward continuing close cooperation national resolution authority european central bank wider stakeholder community ” said dr elke könig chair srb'}
# {'Document': 'SBR 2019 5.docx', 'Dimension 1st': '3', 'Dimension 2nd': '2', 'id': 'SBR 2019 5', 'text': "SRB launches public consultation on its 'Expectations for Banks'\nThe Single Resolution Board (SRB) today launches its first\xa0on its\xa0, which outlines best practice on key aspects of resolvability. The\xa0\xa0is part of the SRB’s commitment to listening to the views of banks and other stakeholders and being transparent about its approaches and decisions.\nThe\xa0sets out the capabilities the SRB expects banks to demonstrate in order to show that they are resolvable. It reflects best practice in and sets benchmarks for assessing resolvability. The document will provide clarity to the market on the actions the SRB expects banks to take.\nWhile the expectations are general, their application will be tailored to each individual bank, based on a dialogue with the SRB’s internal resolution teams. The result will feed into the SRB’s annual resolution work programmes for banks.\nIn line with our intention to consult the industry on key documents, the SRB invites feedback between 23 October and 4 December 2019 – 12:00 (Brussels time) through this\xa0.\nPersonal data and privacy statement\nThe SRB is committed to user privacy. When carrying out public consultations we adhere to the policy on 'protection of individuals with regard to the processing of personal data by the Union institutions, bodies, offices and agencies', based on Regulation (EU) 2018/1725 on processing of personal data by the EU institutions.\xa0.\n", 'processed_text': 'srb launch public consultation expectation bank single resolution board srb today launch first outline best practice key aspect resolvability part srb ’ commitment listening view bank stakeholder transparent approach decision set capability srb expects bank demonstrate order show resolvable reflects best practice set benchmark assessing resolvability document provide clarity market action srb expects bank take expectation general application tailored individual bank based dialogue srb ’ internal resolution team result feed srb ’ annual resolution work programme bank line intention consult industry key document srb invite feedback october december – brussels time personal data privacy statement srb committed user privacy carrying public consultation adhere policy protection individual regard processing personal data union institution body office agency based regulation eu processing personal data eu institution'}
# {'Document': 'SBR 2019 6.docx', 'Dimension 1st': '2', 'Dimension 2nd': '3', 'id': 'SBR 2019 6', 'text': 'SRB Publishes Paper on Public Interest Assessment\nBrussels – 03 07 2019\nThe Single Resolution Board (SRB) has today published a paper outlining its approach to an important element of the resolution framework, the Public Interest Assessment (PIA).\nThe PIA examines whether the resolution of a particular bank that is failing or likely to fail would be necessary, for example to ensure one or more of the following objectives: maintaining financial stability, protecting covered depositors and safeguarding public funds by minimising reliance on extraordinary public financial support. If not, resolution actions would not be taken and national insolvency procedures would apply.\xa0\nThe document gives clarity to the factors the SRB takes into account when conducting a PIA, and explains how the SRB applies the criteria as set out in EU law. The publication of the methodology is aimed at providing more transparency and certainty for banks and the markets.\nSpeaking in Brussels, the Chair of the SRB, Dr. Elke König commented, ‘The resolution framework as an exception to normal insolvency sets strict conditions and the Public Interest Assessment is a core element in this context. Today’s SRB’s publication aims to provide clarity and transparency to all stakeholders.”\nThe approach was developed by the SRB and national resolution authorities, in consultation with the ECB and the EBA, to ensure a common understanding across the Banking Union. It is one of the key policies underpinning the work of the SRB.\n\xa0\nBackground: The Public Interest Assessment (PIA)\nWhen the SRB considers whether to plan for or to take resolution action – both at the resolution planning stage and after a failing or likely to fail (FOLTF) declaration – it performs a PIA. The conclusion of the PIA drives the decision as to whether resolution is to be considered as the preferred option in resolution planning respectively a resolution decision taken and not normal insolvency proceedings pursued in case of a failing bank. The PIA ensures that, in the case of resolution action, it would achieve one or more of the resolution objectives better than would be the case with a national insolvency procedure. The resolutions objectives are, inter alia, avoiding significant adverse effects on financial stability, protecting depositors covered by Directive 2014/49/EU (on Deposit Guarantee Schemes) and safeguarding public funds by minimising reliance on extraordinary public financial support,\n\xa0', 'processed_text': 'srb publishes paper public interest assessment brussels – single resolution board srb today published paper outlining approach important element resolution framework public interest assessment pia pia examines whether resolution particular bank failing likely fail would necessary example ensure one following objective maintaining financial stability protecting covered depositor safeguarding public fund minimising reliance extraordinary public financial support resolution action would taken national insolvency procedure would apply document give clarity factor srb take account conducting pia explains srb applies criterion set eu law publication methodology aimed providing transparency certainty bank market speaking brussels chair srb dr elke könig commented ‘ resolution framework exception normal insolvency set strict condition public interest assessment core element context today ’ srb ’ publication aim provide clarity transparency stakeholder ” approach developed srb national resolution authority consultation ecb ensure common understanding across banking union one key policy underpinning work srb background public interest assessment pia srb considers whether plan take resolution action – resolution planning stage failing likely fail foltf declaration – performs pia conclusion pia drive decision whether resolution considered preferred option resolution pla ...
# {'Document': 'SBR 2019 7.docx', 'Dimension 1st': '2', 'Dimension 2nd': '3', 'id': 'SBR 2019 7', 'text': 'Appointment of SRB Board Member Dominique Laboureix as Secretary-General, ACPR\nThe Single Resolution Board (SRB) congratulates Dominique Laboureix for his appointment as Secretary-General of the French national supervisory and resolution authority, l’Autorité de Contrôle Prudentiel et de Résolution (ACPR). He will move to the ACPR and take up his new position after his mandate as Board Member and Director for Resolution Planning and Decisions ends.\nSince 2015, Mr Laboureix has played a key role in the establishment, development and success of the SRB. He has made a major contribution to its mission to ensure the orderly resolution of failing banks, protecting the taxpayer and promoting financial stability. We are happy that he will continue to be a crucial part of the Single Resolution Mechanism (SRM) and look forward to continuing to work closely with him.\n\xa0\n', 'processed_text': 'appointment srb board member dominique laboureix secretarygeneral acpr single resolution board srb congratulates dominique laboureix appointment secretarygeneral french national supervisory resolution authority l ’ autorité de contrôle prudentiel et de résolution acpr move acpr take new position mandate board member director resolution planning decision end since mr laboureix played key role establishment development success srb made major contribution mission ensure orderly resolution failing bank protecting taxpayer promoting financial stability happy continue crucial part single resolution mechanism srm look forward continuing work closely'}
# {'Document': 'SBR 2019 8.docx', 'Dimension 1st': '2', 'Dimension 2nd': '3', 'id': 'SBR 2019 8', 'text': 'Bank Resolution: Turning Policy into Action - SRB holds its fourth annual conference in Brussels\nToday, the Single Resolution Board (SRB) is holding its fourth conference in Brussels. The annual event brings together industry, public authorities and key stakeholders in bank resolution to assess progress and priorities for action.\xa0\nThe theme this year reflects the SRB’s even greater emphasis on the implementation of the policies and guidance it has developed. The onus is now on the industry to work towards resolvability. In the context of the second Banking Package, discussions will also focus on the progress made in resolution, the liquidity available should a bank fail and operational continuity.\xa0\nThe event will be opened by SRB Chair Elke König,\xa0Competition Commissioner, and the Executive Vice President-designate - Europe fit for the Digital Age, Margrethe Vestager\xa0and UniCredit CEO,\xa0Jean-Pierre Mustier. Other speakers include high-level representatives of banks, central banks and European and international institutions.\nThe end of 2019 will also be marked by the SRB’s first public consultation, which will centre around its ‘Expectations for Banks’ publication. The draft document sets out what the SRB expects banks to demonstrate to show they are resolvable and prepared for crisis management. The consultation will be launched\xa0soon. More details will be available on the SRB website.\xa0\nMeanwhile, the SRB conference of today can be watched online by following\xa0.\xa0The conference features opening addresses and keynotes from:\nElke König, Chair of the Single Resolution Board: “The area of banking resolution is still a relatively new topic. Often, it is only by doing that we learn what works and what still needs to be fine-tuned. We appreciate the feedback and cooperation of industry, and our regulatory partners across the Banking Union and further afield. This month, we will launch a public consultation on our ‘Expectations for Banks’ document and are looking forward to more valuable input.”\nSasha Mills, Executive Director, Bank of England:\xa0“The final major piece in the UK resolution regime for banks is making firms accountable for their own resolvability under the recently published Resolvability Assessment Framework – “turning policy into action”.\nJean Pierre Mustier, CEO, Unicredit:"The EU framework on resolution is broadly in place. Authorities and banks are working hard to make it more operational. We still need two things: first, temporary liquidity to banks in resolution, without further burdening the banking system. Second, a level playing field with other jurisdictions, such as the US, supporting EU banks competitiveness. More generally, the EU should perform a proper and coordinated study on the full impact of all regulatory measures on banks, including the market’s ability to absorb new MREL instruments issuances.”\n', 'processed_text': 'bank resolution turning policy action srb hold fourth annual conference brussels today single resolution board srb holding fourth conference brussels annual event brings together industry public authority key stakeholder bank resolution ass progress priority action theme year reflects srb ’ even greater emphasis implementation policy guidance developed onus industry work towards resolvability context second banking package discussion also focus progress made resolution liquidity available bank fail operational continuity event opened srb chair elke könig competition commissioner executive vice presidentdesignate europe fit digital age margrethe vestager unicredit ceo jeanpierre mustier speaker include highlevel representative bank central bank european international institution end also marked srb ’ first public consultation centre around ‘ expectation bank ’ publication draft document set srb expects bank demonstrate show resolvable prepared crisis  ...
# {'Document': 'SBR 2019 9.docx', 'Dimension 1st': '3', 'Dimension 2nd': '2', 'id': 'SBR 2019 9', 'text': 'AS PNB Banka: SRB Decides No Resolution Required\xa0\nFollowing the European Central Bank’s assessment of AS PNB Banka as failing or likely to fail, the Single Resolution Board has today decided that resolution action is not necessary. The Latvian bank will be wound up under national law.\nThe SRB assessed the situation and concurred with the ECB’s assessment of the bank. It concluded that there are no available supervisory or private sector measures that could prevent its failure.\nThe Board carried out a public interest assessment and found that resolution action was not necessary. In particular, PNB Banka does not provide critical functions to the economy and its failure is not expected to have an adverse impact on financial stability in Latvia or other EU Member States.\nThe National Resolution Authority in Latvia, the Financial and Capital Market Commission, will implement the decision in accordance with national law.\nEligible deposits up to €100,000 are safeguarded in accordance with the Latvian law transposing Directive 2014/49/EU. Depositors in Latvia can contact the\xa0, which is the administrator of the Latvian deposit guarantee fund, for more information.\n\n\n\n\n\n\xa0\nMore information:\n\n\n\xa02014/59/EU of the European Parliament and of the Council of 15 May 2014 establishing a framework for the recovery and resolution of credit institutions and investment firms and amending Council Directive 82/891/EEC, and Directives 2001/24/EC, 2002/47/EC, 2004/25/EC, 2005/56/EC, 2007/36/EC, 2011/35/EU, 2012/30/EU and 2013/36/EU, and Regulations (EU) No 1093/2010 and (EU) No 648/2012, of the European Parliament and of the Council.\n\xa0(EU) No 806/2014 of the European Parliament and of the Council of 15 July 2014 establishing uniform rules and a uniform procedure for the resolution of credit institutions and certain investment firms in the framework of a Single Resolution Mechanism and a Single Resolution Fund and amending Regulation (EU) No 1093/2010.\n\xa02014/49/EU of the European Parliament and of the Council of 16 April 2014 on deposit guarantee schemes.\n', 'processed_text': 'pnb banka srb decides resolution required following european central bank ’ assessment pnb banka failing likely fail single resolution board today decided resolution action necessary latvian bank wound national law srb assessed situation concurred ecb ’ assessment bank concluded available supervisory private sector measure could prevent failure board carried public interest assessment found resolution action necessary particular pnb banka provide critical function economy failure expected adverse impact financial stability latvia eu member state national resolution authority latvia financial capital market commission implement decision accordance national law eligible deposit € safeguarded accordance latvian law transposing directive eu depositor latvia contact administrator latvian deposit guarantee fund information information eu european parliament council may establishing framework recovery resolution credit institution investment firm amending council directive eec directive ec ec ec ec ec eu eu eu regulation eu eu european parliament council eu european parliament council july establishing uniform rule uniform procedure resolution credit institution certain investment firm framework single resolution mechanism single resolution fund amending regulation eu eu european parliament council april deposit guarantee scheme'}
# {'Document': 'SBR 2019 10.docx', 'Dimension 1st': '2', 'Dimension 2nd': '3', 'id': 'SBR 2019 10', 'text': "SRB 2018 Annual Report launched\n‘Complete resolution plans for all banking groups under SRB remit by 2020,' says Elke König\xa0\n\xa0\nBrussels – 01 07 2019\nThe SRB today published its 2018 Annual Report, which gives an overview of its work and highlights achievements and progress.\xa0\nWork on more than 100 resolution plans for banks under the SRB's remit progressed in close collaboration with national resolution authorities (NRAs) during 2018. In 2018, the SRB differentiated between banks active entirely in the Banking Union, i.e. banks without a resolution college, and the most complex, internationally active banks, i.e. banks with resolution colleges, for which the planning cycle reaches well into 2019. The resolution planning cycle for 2018/2019 marks a type of transition phase in order to get to accelerate work and get to the steady state for resolution planning.\xa0\nThe SRB intends to use the transition phase to implement the new provisions of the risk reduction package, which was agreed upon by EU lawmakers in 2018. Political agreement on the Common Backstop marked another important milestone for the SRB’s work.\nAs part of its commitment to be ever more transparent, the SRB published its detailed MREL policy and communicated extensively with the banks under its remit to reach its goal to have fully-fledged resolution plans for all banking groups under its remit by 2020.\nSpeaking at the launch of the report, SRB Chair Elke König said ‘2018 marked ten years since the economic crash, but it also marked the beginning of a new phase for the SRB. We now move our focus from establishing the broad policies to implementing them and thus making banks truly resolvable. This means considerable efforts for the banks, the National authorities and us but should protect the taxpayer from future bail-outs, while promoting financial stability.'\nElke König will present the Report to the European Parliament's ECON Committee at a public hearing on July 23, 2019.\n\xa0\n\xa0\n", 'processed_text': 'srb annual report launched ‘ complete resolution plan banking group srb remit say elke könig brussels – srb today published annual report give overview work highlight achievement progress work resolution plan bank srbs remit progressed close collaboration national resolution authority nra srb differentiated bank active entirely banking union ie bank without resolution college complex internationally active bank ie bank resolution college planning cycle reach well resolution planning cycle mark type transition phase order get accelerate work get steady state resolution planning srb intends use transition phase implement new provision risk reduction package agreed upon eu lawmaker political agreement common backstop marked another important milestone srb ’ work part commitment ever transparent srb published detailed mrel policy communicated extensively bank remit reach goal fullyfledged resolution plan banking group remit speaking launch report srb chair elke könig said ‘ marked ten year since economic crash also marked beginning new phase srb move focus establishing broad policy implementing thus making bank truly resolvable mean considerable effort bank national authority u protect taxpayer future bailouts promoting financial stability elke könig present report european parliament econ committee public hearing july'}
# {'Document': 'SBR 2019 11.docx', 'Dimension 1st': '3', 'Dimension 2nd': '3', 'id': 'SBR 2019 11', 'text': 'SRB updates MREL policy to reflect new Capital Requirements Regulation\nThe Single Resolution Board has today published an\xa0\xa0to its policy on minimum requirement for own funds and eligible liabilities (MREL) in light of the publication of the Banking Package in the Official Journal of the EU on 7 June 2019.\xa0\nThis publication is an addendum to the 2018 SRB MREL policy for the second wave of resolution plans (published on 16 January 2019), which applies to all institutions for which MREL decisions have or will be taken for the 2018 and 2019 resolution planning cycles. It aims to inform institutions in the SRB’s remit about regulatory changes in the Capital Requirements Regulation (CRR) in the area of resolution, and their interaction with the SRB’s MREL decisions.\nThe publication focuses on the total loss absorbing capacity (TLAC) requirements for globally systemically important institutions (G-SIIs) of Articles 92a and 92b and the permission regime of Article 78a to replace or reduce eligible liabilities instruments for all banks in Regulation (EU) 2019/876 (CRR2). These requirements will be applicable as of 27 June 2019. The SRB provides in particular operational guidance to banks on the arrangements for the permissions process.\nA technical press briefing on this topic will be held\xa0in the coming days.\xa0An invitation will be sent separately.\n\n', 'processed_text': 'srb update mrel policy reflect new capital requirement regulation single resolution board today published policy minimum requirement fund eligible liability mrel light publication banking package official journal eu june publication addendum srb mrel policy second wave resolution plan published january applies institution mrel decision taken resolution planning cycle aim inform institution srb ’ remit regulatory change capital requirement regulation crr area resolution interaction srb ’ mrel decision publication focus total loss absorbing capacity tlac requirement globally systemically important institution gsiis article b permission regime article replace reduce eligible liability instrument bank regulation eu crr requirement applicable june srb provides particular operational guidance bank arrangement permission process technical press briefing topic held coming day invitation sent separately'}
# {'Document': 'SBR 2019 12.docx', 'Dimension 1st': '2', 'Dimension 2nd': '2', 'id': 'SBR 2019 12', 'text': 'Banking Union financial integration: time to consolidate trust - Eurofi Article by Elke König\nExtensive literature exists on the benefits of financial integration and consolidation of banks. From the perspective of the Single Resolution Board, whose mandate focuses on achieving banks’ resolvability, having strong European banks is a natural aspiration. Where there is a solid business case, consolidation can bring economies of scale and increase profitability. It can improve diversification of risks within banking groups. It can also increase banks’ access to capital markets and decrease their funding cost, ultimately facilitating their build-up of loss absorption capacity to meet the so-called Minimum Requirement of Eligible Liabilities (MREL).\nMoreover, like cross-border capital markets,\xa0cross-border banks can play the important role of reducing risks through private risk sharing\xa0within the Banking Union. Indeed, cross-border banks are better equipped to withstand and absorb idiosyncratic shocks that may affect one or another Member State. Beyond the perspective of banks and Member States, it is important to look at this topic from the perspective of the investor too. Financial integration could lead to more efficient markets and provide financial services users with better choices.\nThis being said, consolidation within the banking sector should not be seen as a panacea or a short cut to avoid necessary reforms. In this sense, it is crucial for a resolution authority that consolidation facilitates rather than hinders the resolvability of a bank, in line with the Single Resolution Board’s resolvability expectations.\nOverall, the advantages of banks’ consolidation seem therefore evident. In addition, the establishment of the institutional infrastructure of the Banking Union can also be seen as a favourable element: although the third pillar, common deposit insurance, is yet to be built, a single supervisory mechanism and a single resolution mechanism are up and running.\nIn spite of all of this, financial integration within the Banking Union is still lagging behind. Several studies have found multiple causes behind this trend. Market factors surely play a prominent role. However, there are also challenges that could be addressed by policy-makers and regulators.\nAmong these, EU legislators and regulators should keep up the momentum on the clean-up of banks’ balance sheets. The harmonisation of relevant legislation, such as insolvency proceedings, could also contribute to remove barriers for the cross-border consolidation of banks.\xa0\nFinally, yet importantly, rule-makers and regulators should resist the temptation of ring-fencing capital and liquidity resources, as this can lead to suboptimal location and rigidity in the deployment of such resources. Regrettably, the recently agreed banking package does not mark a step forward on this aspect. Rather, it runs the risks of, first, fragmenting decision-making within the Banking Union on external MREL, and second, ring-fencing of internal MREL. The Single Resolution Board already invests and will continue to invest significant resources to reach joint decisions with national authorities on resolution plans, calibration and location of MREL, and bail-in playbooks. Such day-to-day cooperation should increase mutual trust within the Banking Union, and ultimately be reflected in a future revised regulatory framework.\nIn a word, Rome was not built in a day. Just like in the United States, where financial integration took decades, it is not surprising that the road for Banking Union integration is still long and winding. However, the direction of travel should remain clear, and the need to consolidate trust along the way should be high on everybody’s agenda.\n', 'processed_text': 'banking union financial integration time consolidate trust eurofi article elke könig exten ...
# {'Document': 'SBR 2019 13.docx', 'Dimension 1st': '3', 'Dimension 2nd': '2', 'id': 'SBR 2019 13', 'text': "SRB announces the appointment of new Board Member Sebastiano Laviola\xa0\nThe Single Resolution Board (SRB) announces the appointment of Mr Sebastiano Laviola as Member of the Board and Director of Resolution Strategy and Cooperation. He will take up his duties on 1 May, 2019.\nMr Laviola, an Italian national, is a Central Director of Banca d’Italia, where he has served since 1986. He has spent most of his career in the Banking and Financial Supervision Department, dealing with analytical issues and coordinating policy on international regulation. He has been a continuous member of and chaired international supervisory committees and working groups. In 2012, Mr Laviola was seconded to the Permanent Representation of Italy to the EU in Brussels as Financial Services Attaché, where he negotiated financial services and Banking Union legislation.\nIn line with\xa0, which set up the SRB, the Commission in consultation with the SRB established a shortlist for the function of Member of the Board and Director of Resolution Strategy and Cooperation. The Commission proposed Mr Laviola as a candidate to the European Parliament. After the European Parliament gave its approval to the Commission's proposal on 14 March 2019, the Council, acting by qualified majority, adopted the appointment of Mr Laviola on 8 April 2019. He was selected through a stringent recruitment process.\nHe will replace Mr Mauro Grande who announced his resignation in July 2018.\n“Mr Laviola has a wealth of experience in banking regulation and policy, which will be a real asset to the SRB. The Vice-Chair, Board Members and I look forward to welcoming him and working closely with him. His knowledge will help us continue in our mission to foster bank resolvability, contribute to financial stability and protect European taxpayers.\n“I would also like to thank Mauro Grande for his dedication and hard work since he joined the SRB in 2015. We wish him every success for the future.”\nElke König, Chair of the Single Resolution Board.\n“I am very pleased to be joining the SRB in the next weeks. In the light of my previous experience in banking and financial regulation and in the negotiation of the legislation on Banking Union, I am committed to making a contribution to improving bank resolvability.”\nSebastiano Laviola, newly appointed Member of the Board.\n", 'processed_text': 'srb announces appointment new board member sebastiano laviola single resolution board srb announces appointment mr sebastiano laviola member board director resolution strategy cooperation take duty may mr laviola italian national central director banca ’ italia served since spent career banking financial supervision department dealing analytical issue coordinating policy international regulation continuous member chaired international supervisory committee working group mr laviola seconded permanent representation italy eu brussels financial service attaché negotiated financial service banking union legislation line set srb commission consultation srb established shortlist function member board director resolution strategy cooperation commission proposed mr laviola candidate european parliament european parliament gave approval commission proposal march council acting qualified majority adopted appointment mr laviola april selected stringent recruitment process replace mr mauro grande announced resignation july “ mr laviola wealth experience banking regulation policy real asset srb vicechair board member look forward welcoming working closely knowledge help u continue mission foster bank resolvability contribute financial stability protect european taxpayer “ would also like thank mauro grande dedication hard work since joined srb wish every success future ” elke könig chair single resolution board “ pleased joining srb next week light previous experience banking financial regulation negotiation l ...
# {'Document': 'SBR 2019 14.docx', 'Dimension 1st': '3', 'Dimension 2nd': '3', 'id': 'SBR 2019 14', 'text': 'Process Launched to Select and Appoint Three New SRB Board Members\n\xa0\nBrussels – 27 03 2019\nThe European Commission, in consultation with the Single Resolution Board (SRB), has launched the process to select and appoint three new Board Members.\xa0\nThe terms of office for the Board Members appointed in 2014, which are not renewable under the Single Resolution Mechanism, will come to an end in December 2019.\xa0The new Board Members will be appointed to replace the outgoing ones.\nDr Timo Löyttyniemi, Vice Chair and Director of the Single Resolution Fund and Corporate Services, Antonio Carrascosa, Board Member and Director of Resolution Planning and Decisions and Dominique Laboureix, Board Member and Director of Resolution Planning and Decisions continue to be active and committed to the work of the SRB until the new Members are appointed and take up office.\nThe European Commission, in consultation with the SRB, has published the following notices:\n\n\nThe deadline for applications is 29 04 2019.\n\xa0\n', 'processed_text': 'process launched select appoint three new srb board member brussels – european commission consultation single resolution board srb launched process select appoint three new board member term office board member appointed renewable single resolution mechanism come end december new board member appointed replace outgoing one dr timo löyttyniemi vice chair director single resolution fund corporate service antonio carrascosa board member director resolution planning decision dominique laboureix board member director resolution planning decision continue active committed work srb new member appointed take office european commission consultation srb published following notice deadline application'}
# {'Document': 'SBR 2019 15.docx', 'Dimension 1st': '2', 'Dimension 2nd': '3', 'id': 'SBR 2019 15', 'text': 'SRB publishes Framework for Valuation\xa0\n\xa0\nBrussels – 19 February 2019\nThe Single Resolution Board (SRB) has today published its Framework for Valuation.\nThe objective of this Framework for Valuation is to provide independent valuers and the general public with an indication of the SRB’s expectations regarding the principles and methodologies for valuation reports as set out in the legal framework. This refers to the so-called Valuation 2 - either provisional or definitive, as the case may require – as well as Valuation 3.\nThe Framework for Valuation aims at reducing uncertainty for both the independent valuers and the SRB, providing indications that are necessary for achieving the goals of the valuation, subsequently enhancing comparability and consistency of valuations across future resolution cases.\nSpeaking in Brussels, the Chair of the SRB, Dr Elke König said ‘This Framework is about, ensuring the consistency of the valuation reports which inform the decisions of the Single Resolution Board. Though directed at the independent valuation experts, the institutions will also benefit from a better understanding of valuation in resolution which will help them to increase its preparedness for resolution, ultimately improving their resolvability.’\nThe European Banking Authority (EBA) and the SRB have collaborated closely in their respective work on valuation. Additionally, the EBA and the SRB will continue to make progress together to define expectations towards the provision of accurate and timely information that is necessary for the performance of valuations in resolution.\n', 'processed_text': 'srb publishes framework valuation brussels – february single resolution board srb today published framework valuation objective framework valuation provide independent valuer general public indication srb ’ expectation regarding principle methodology valuation report set legal framework refers socalled valuation either provisional definitive case may require – well valuation framework valuation aim reducing uncertainty independent valuer srb providing indication necessary achieving goal valuation subsequently enhancing comparability consistency valuation across future resolution case speaking brussels chair srb dr elke könig said ‘ framework ensuring consistency valuation report inform decision single resolution board though directed independent valuation expert institution also benefit better understanding valuation resolution help increase preparedness resolution ultimately improving resolvability ’ european banking authority srb collaborated closely respective work valuation additionally srb continue make progress together define expectation towards provision accurate timely information necessary performance valuation resolution'}
# {'Document': 'SBR 2019 16.docx', 'Dimension 1st': '4', 'Dimension 2nd': '2', 'id': 'SBR 2019 16', 'text': 'European banking – there is strength in diversity - Eurofi article by Elke König\nIf the European Union’s motto is ‘United in Diversity’, then perhaps the Banking Union’s motto should be something along the lines of ‘Strength in Diversity’.\xa0\nThe Banking Union is a diverse mosaic of small and complex financial institutions. In some states, the banking market is dominated by foreign operators. In others it is small banks that have the lion’s share of the market. And in others still, the market is largely made up of just a few large banks. The structure of individual markets within the Banking Union varies hugely reflecting not least different traditional development. This diversity in structures is not necessarily a bad thing. For example, a large bank poses a serious risk to financial stability if it cannot be made resolvable; smaller banks may not have the economies of scale to be viable in the long-term. There are pros and cons to each model – the important thing from a financial stability point of view is that small banks and big banks have sustainable business models. Regulation and supervision have to cope with the variety of business models. Just to name two points: Regulation has to be proportionate, there is no “one size fits all” and in a single market the diversity in national rules has to be overcome to facilitate mergers and acquisitions.\nA good regulatory framework can facilitate this, but of course, the role of the regulator is not to ensure every bank can make a profit. Every bank, big and small, must be in a position to comply with regulatory standards and bear the cost that is inherent in the safety net that regulation provides to society. That said, the regulatory landscape should facilitate as much as possible the natural behavior of a free market in the European banking sector. The challenge for regulation has always been to recognize that one size does not fit all, while also balancing the need for a level-playing field.\nHowever, it is not just about regulation for the financial industry. A fully functioning Capital Markets Union, which allowed for investment to flow easily across the euro area, is much needed and would do much to ensure that banks have an enlarged “home market for capitalization and investment”. A proper, fully functioning capital markets union in Europe would allow for greater integration of investment, allowing for the possibility of more consolidation, creating banks ready to operate right across the 19 Eurozone countries. This would introduce competition for the consumer, but it would also diversify the banking market within many member states, which would be a good thing. Unlike the Banking Union however, the Capital Markets Union is more of a concept, and idea or a notion, rather than a concrete legislative framework.\nThere is also work to be done in harmonising insolvency procedures. In the Banking Union itself we have 19 different insolvency procedures, so banks and their investors will have to contend with and learn about many different legal systems just to invest in a market that is outside their home member state. The single market has still a way to go.\nIt is also true that completing the Banking Union and having all European deposits protected at EU level, in a harmonized way, would promote stability and confidence if and when the next crisis strikes.\nThere probably is a need for consolidation in the European banking market in order to remove overcapacity and ensure greater profitability overall. Some banks will simply have to exit the market; mergers and acquisitions can play a significant role in consolidation. In any case, a completed Banking Union and a full Capital Markets Union would be a solid framework so that the markets can be left to play their part, strengthening the sector going forward and thus helping to promote financial stability.\nThis article  ...
# {'Document': 'SBR 2019 17.docx', 'Dimension 1st': '2', 'Dimension 2nd': '3', 'id': 'SBR 2019 17', 'text': 'SRB Publishes Second Part of 2018 MREL Policy\nBrussels – 16/01/2019\nThe Single Resolution Board (SRB) has today published the second part of its 2018 policy on the minimum requirement for own funds and eligible liabilities (MREL) pertaining to the second wave of resolution plans; i.e. the plans for the most complex banking groups. \xa0\xa0\nMREL represents one of the key tools in enhancing banks’ resolvability. The SRB continues to develop its MREL policy, step-by-step. This gives banks the clarity needed on the SRB’s requirements for them to build up MREL.\nConcretely, in order to increase the quantity and quality of MREL, this second part of the 2018 MREL policy introduces a series of new features to strengthen banks’ resolvability within the Banking Union. Among them, the main new ones are: a refined approach for eligible instruments for consolidated MREL-targets, increased binding subordination requirements and, last but not least, the introduction of binding MREL targets at individual level. \xa0\nThe SRB will continue to develop its MREL policy going forward. After the adoption of the Banking Package, the SRB policy will need to be adapted to address in particular the TLAC implementation and the new internal MREL requirements.\n', 'processed_text': 'srb publishes second part mrel policy brussels – single resolution board srb today published second part policy minimum requirement fund eligible liability mrel pertaining second wave resolution plan ie plan complex banking group mrel represents one key tool enhancing bank ’ resolvability srb continues develop mrel policy stepbystep give bank clarity needed srb ’ requirement build mrel concretely order increase quantity quality mrel second part mrel policy introduces series new feature strengthen bank ’ resolvability within banking union among main new one refined approach eligible instrument consolidated mreltargets increased binding subordination requirement last least introduction binding mrel target individual level srb continue develop mrel policy going forward adoption banking package srb policy need adapted address particular tlac implementation new internal mrel requirement'}
# {'Document': 'SBR 2019 18.docx', 'Dimension 1st': '3', 'Dimension 2nd': '2', 'id': 'SBR 2019 18', 'text': 'Single Resolution Board launches 2020 resolution reporting data request\nAs communicated during the SRB Industry dialogue on\xa0, the SRB has today launched the process for the 2020 data collection cycle for Resolution Reporting. The details of the scope, content and deadlines for resolution reporting to the SRB are now available on the dedicated\xa0.\nIn terms of the content and format of the data request, the SRB has made an effort to align with the\xa0. Where necessary to fulfil its mandate as Group Level Resolution Authority, the SRB has extended the data request. In particular, the SRB will be requesting Additional Liability Data in preparation for the 2020 resolution planning cycle. This data request is aligned with the ongoing work undertaken at the EBA on the development of Implementing Technical Standard (ITS) on reporting, while addressing some specificities of the resolution strategies. Given the temporary nature of this data request – until it is replaced by the RTS – the data collection for this specific report will be in Excel format in 2020. This data may be collected in XBRL in future collections if fully integrated to EBA’s ITS (see\xa0\xa0for further details).\nAs was the case during previous collection cycles, for the 2020 data collection the SRB will be collecting data from banks, via National Resolution Authorities (NRAs), for those banks under the SRB’s remit. NRAs will inform banks of their resolution reporting obligations in October 2019, once these are finalised in collaboration with the SRB.\xa0\nThe deadline for delivery by banks to NRAs is March 31st 2020 for the Liability reports (main report in XBRL, and Additional Liability Data in Excel, as mentioned above). All other resolution reports are due by banks by April 30th 2020.\nFor more information or questions, banks are invited to contact their NRAs.\n', 'processed_text': 'single resolution board launch resolution reporting data request communicated srb industry dialogue srb today launched process data collection cycle resolution reporting detail scope content deadline resolution reporting srb available dedicated term content format data request srb made effort align necessary fulfil mandate group level resolution authority srb extended data request particular srb requesting additional liability data preparation resolution planning cycle data request aligned ongoing work undertaken development implementing technical standard reporting addressing specificity resolution strategy given temporary nature data request – replaced rts – data collection specific report excel format data may collected xbrl future collection fully integrated ’ see detail case previous collection cycle data collection srb collecting data bank via national resolution authority nra bank srb ’ remit nra inform bank resolution reporting obligation october finalised collaboration srb deadline delivery bank nra march st liability report main report xbrl additional liability data excel mentioned resolution report due bank april th information question bank invited contact nra'}
# {'Document': 'SBR 2019 19.docx', 'Dimension 1st': '1', 'Dimension 2nd': '3', 'id': 'SBR 2019 19', 'text': 'A common set of rules for liquidation for small and medium-sized banks - Eurofi article by Elke König\nThe definition of a bank’s size as small, medium or big is relative. The Banking Union (BU) established a definition for significant institutions and a dedicated framework. However, there are many other institutions as well as significant institutions, which are not small but for which resolution will not be the option in case of failure. The EU framework makes clear and we have repeatedly stressed that resolution is for the few, not the many.\nThe decision to put a failing institution into resolution depends on the outcome of a “public interest assessment” (PIA), determining if the preservation of a bank’s critical functions is required to maintain financial stability. If the PIA’s outcome is negative, a failing bank will be sent into national insolvency. In order to increase transparency the SRB recently published a paper on PIA presenting the methodology and how the SRB assesses the criteria set out by EU law.\nIn due consideration of proportionality in resolution planning, the loss absorption requirements for each institution are carefully adjusted to the choice of resolution tools. Banks, for which in case of failure no resolution is foreseen, do not have to build up Minimum Requirement for own funds and Eligible Liabilities (MREL) on top of their supervisory capital requirements for going concern. Hence, those banks do not face further costs apart from the regular costs for supervisory compliance and basic recovery and resolution planning. In contrast, for banks, whose preferred strategy is resolution, the SRB’s MREL policy and its expectations for resolvability provide for certain adjustments to allow for proportionality as well.\nThe SRB can also grant transitional periods for banks, based on features such as market conditions or a bank’s liability structure or market access, in order to allow for a gradual build-up of MREL requirements. However, the rules require, that before using the SRF significant losses must be absorbed by the bank’s equity- and bondholders. And it is undisputed that sufficient MREL is needed to implement any resolution strategy. In this regard the SRB must strike a careful balance between feasibility of the build-up of MREL and the credibility of the resolution strategy.\nBuilding up the capital buffers may be challenging for smaller fully deposit funded banks. For this reason, a common set of rules for winding down such banks could be beneficial - for some SRB banks and all less significant banks. While we have one common European resolution scheme, in the BU we are faced with 19 different national insolvency laws when winding-down a (cross-border) bank. A set of common standards, practices and harmonised rules for the liquidation of banks would considerably facilitate\nresolution planning, increase predictability and prevent diverging outcomes in different member states. Needless to say that administrative procedures might be preferable to judicial procedures. At the end of this process might stand the creation of a European bank liquidation regime - a European FDIC. Not only would this ensure centralised decision-making, but also the application of a harmonized and effective toolbox supported by a European deposit insurance. With this being a long decision-making process, legislators should wait no longer.\nThis article\xa0first\xa0appeared in\xa0, the magazine of the Eurofi forum\xa0held in Helsinki in September 2019.\n', 'processed_text': 'common set rule liquidation small mediumsized bank eurofi article elke könig definition bank ’ size small medium big relative banking union bu established definition significant institution dedicated framework however many institution well significant institution small resolution option case failure eu framework make clear repeatedly stressed resolu ...
# {'Document': 'SBR 2019 20.docx', 'Dimension 1st': '2', 'Dimension 2nd': '1', 'id': 'SBR 2019 20', 'text': 'Single Resolution Board expectations to ensure resolvability of banks in the context of Brexit\nThe SRB has the mandate to ensure resolvability of all the banks under its remit. The SRB expects all banks active in the Banking Union to meet a specific set of resolvability conditions. This paper focuses on six main areas: MREL eligibility, internal loss absorbency, operational continuity, access to FMIs, governance and management information systems. The requirements apply to Banking Union banks, be it either banks with significant activities in third countries or Banking Union subsidiaries of third country banking groups.\nAs a result of the UK leaving the EU, some UK or third country banking groups have decided to relocate activities currently UK-based to the EU27 or to increase the extent or scope of existing activities therein. Also, some banks under the SRB’s remit may have significantly increased business or operational activities in third countries.\n', 'processed_text': 'single resolution board expectation ensure resolvability bank context brexit srb mandate ensure resolvability bank remit srb expects bank active banking union meet specific set resolvability condition paper focus six main area mrel eligibility internal loss absorbency operational continuity access fmis governance management information system requirement apply banking union bank either bank significant activity third country banking union subsidiary third country banking group result uk leaving eu uk third country banking group decided relocate activity currently ukbased eu increase extent scope existing activity therein also bank srb ’ remit may significantly increased business operational activity third country'}

# %% [markdown]
# ## Convert texts to txt

# %%
import docx
from tqdm import tqdm_notebook

documents_docx_list = [os.path.join(DOCUMENTS_DOCX_FOLDER, filename) for filename in os.listdir(DOCUMENTS_DOCX_FOLDER)]

def getText(filename):
    """
    Extract text from a docx file
    """
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

def create_textfilename(docx_file_name):
    """
    Generate a filename of the txt file based on the filename of the docx file
    """
    pathlist = list(os.path.split(docx_file_name))
    pathlist[-2] = TEXTFILES_FOLDER
    newpath = os.path.join(*pathlist)
    filename, file_extension = os.path.splitext(newpath)
    newfilenm = filename + '.txt'
    return newfilenm

def read_texts():
    """
    Read the text from all docx files
    Returns a dict with keys = docx filenames and values are texts
    Also stores all texts as .txt
    """
    texts = {}
    for filename in tqdm_notebook(documents_docx_list):
        if '~$' in filename:
            continue
        text = getText(filename)
        textfilenm = create_textfilename(filename)
        filenm_short = os.path.splitext(os.path.split(textfilenm)[-1])[0]
        texts[filenm_short] = text
        
        with open(textfilenm, 'wt') as out:
            out.write(text)
        
    return texts
        
texts = read_texts()        
print(len(texts.keys()))
print(list(texts.items())[:3])
# Out:
# /home/hugo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/1302 [00:00<?, ?it/s]
# 1302
# [('ESMA 2019 93', 'ESMA CONSULTS ON THE COMMERCIAL TERMS FOR PROVIDING CLIENT CLEARING SERVICES UNDER EMIR\n03 October 2019\xa0\nPOST TRADING\nThe European Securities and Markets Authority (ESMA), the EU’s securities markets regulator, has today published a\xa0\xa0(CP) on draft technical advice to the European Commission (EC) on specifying the conditions under which commercial terms are to be considered fair, reasonable, non-discriminatory and transparent (FRANDT) where clearing service providers offer clearing services to clients.\nDuring the implementation of EMIR’s clearing obligation, several counterparties have experienced issues around access to clearing. In response to this access issue EMIR Refit has introduced a number of measures to address it, including the FRANDT requirements.\nThe aim of FRANDT for client clearing services\nThe FRANDT requirements are part of a broader set of regulatory efforts to enhance access to clearing. The proposal on how to specify the conditions under which commercial terms are to be considered fair, reasonable, non-discriminatory and transparent aims to strike the right balance between maintaining providers’ ability to develop their client clearing offerings and to manage their risk, while ensuring the fundamental principles of FRANDT in how these services are offered in order to facilitate access to clearing for all types of clients.\nThe FRANDT requirements should not result in price regulation and should continue to allow providers to control the risks related to their clearing services. However, where clearing services are provided, whether directly or indirectly, providers should offer and provide those services under fair, reasonable, non-discriminatory and transparent commercial terms.\nThe CP sets out the requirements for FRANDT commercial terms, based on the four criteria listed under Article 4(3a) of EMIR, namely:\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 fairness and transparency;\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 unbiased and rational contractual arrangements;\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 to facilitate clearing services and prices to be fair and non-discriminatory; and\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 risk control criteria.\nNext steps\xa0\nESMA will consider all comments received by 2 December 2019 and expects to publish a final report and to submit its technical advice to the EC in Q1 2020.\n'), ('EBA 2019 PR 29', 'EBA publishes Opinion on the regulatory treatment of non-performing exposure securitisations\xa0\n23 October 2019\nThe European Banking Authority (EBA) published today an Opinion on the regulatory treatment of securitisations of non-performing exposures (NPE). Securitisations can play an instrumental role in reducing NPE stocks in credit institutions’ balance sheets but such a role may be hindered by certain provisions in the EU law securitisation framework. This Opinion recommends various amendments to the Capital Requirements Regulation (CRR) as well as to the Securitisation Regulation to remove the identified constraints. The Opinion is addressed at the European Commission and contributes to the objectives of the Council of the EU’s “Action plan to tackle non-performing loans in Europe”. A copy of the Opinion has been sent to the European Parliament and the Council.\nNPE securitisations are transactions backed by pools comprised exclusively or almost exclusively of NPE at the time of inception. Though structurally similar to other securitisations, the underlying assets have distinctive features that set NPE securitisations apart from those from an economic substance perspective, namely due to the large discount on their nominal value and their specific underlying risks.\xa0\xa0\nThe Opinion explains that the regulatory framework imposes certain constraints on credit institutions using securitisation technology to dispose of NPE holdings, namely:\nVery high capital requirements on investor credit institutions under the CRR: the pre-eminent securitisation capit ...

# %% [markdown]
# ## Combine text and labels

# %%
from tqdm import tqdm_notebook

for label_line in tqdm_notebook(labels):
    document_name = label_line["Document"]
    document_id = os.path.splitext(document_name)[0]
    label_line['id'] = document_id
    
    text = texts[document_id]
    label_line['text'] = text

raw_data = {line['id']: line for line in labels}
with open(RAW_DATA_JSON_FILE, 'wt') as out:
    json.dump(raw_data, out)
# Out:
# /home/hugo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
#   0%|          | 0/1302 [00:00<?, ?it/s]

# %% [markdown]
# ## Preprocess Texts

# %%
institutions = set()
for key in raw_data.keys():
    institution = key.split(' ')[0].lower()
    institutions.add(institution)
    
print(institutions)
#TODO: add more institutions
# Out:
# {'eige', 'eda', 'ecdc', 'eit', 'ema', 'euipo', 'europol', 'easa', 'eu-lisa', 'eea', 'berec', 'emsa', 'sbr', 'cepol', 'cvpo', 'esma', 'fra', 'eba', 'efca', 'eiopa', 'easo', 'etf', 'cedefop', 'echa', 'acer', 'frontex', 'eurojust', 'era', 'emcdda', 'eurofound', 'efsa', 'cdt', 'eu-osha', 'enisa'}

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import re
stopWords = set(stopwords.words('english'))


remove_digits = str.maketrans(' ', ' ', string.digits)
remove_punct = str.maketrans(' ', ' ', string.punctuation)
# remove_stopwords = str.maketrans(' ', ' ', stopWords)



lemmatizer = WordNetLemmatizer()

def process_word(word:str):
    word = word.lower()
    word = lemmatizer.lemmatize(word)
    
    return word

# def remove_word(word):
#     if word in stopWords:
#         return True
#     elif word.startswith('\\u'):
#         return True
#     elif word in "!@#$%*()_+-=?/<,>.":
#         return True
#     return False

def preprocess_text(text):
    text = text.lower()
    text = text.translate(remove_punct)
    text = text.translate(remove_digits)
#     text = text.translate(remove_stopwords)
    text = re.sub(r'\u200b', ' ', text)
    text = re.sub(r'\n', ' ', text)
    wordlist = word_tokenize(text)
    wordlist = [lemmatizer.lemmatize(word) for word in wordlist if not (word in stopWords or word in institutions)]
    
    processed_text = ' '.join(wordlist)
    
    return processed_text
#     input(wordlist)

# %%
for identifier, data_line in tqdm_notebook(raw_data.items()):
    text = data_line['text']
    processed_text = preprocess_text(text)
    raw_data[identifier]['processed_text']=processed_text
    
print(list(raw_data.items())[0])
# Out:
# /home/hugo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
#   0%|          | 0/1302 [00:00<?, ?it/s]
# ('ACER 2019 1', {'Document': 'ACER 2019 1.docx', 'Dimension 1st': '1', 'Dimension 2nd': '1', 'id': 'ACER 2019 1', 'text': "ACER analyses national methodologies for electricity transmission tariffs in the EU\n\n23/12/2019\nThe European Union Agency for the Cooperation of Energy Regulators (ACER) released today a report reviewing the status of methodologies for electricity transmission tariffs in the European Union Member States. \n\nThis report\u200b is a contribution towards the Clean Energy Package objective to increase transparency and comparability in tariff-setting. The report also presents the findings of ACER's monitoring of transmission charges paid by producers. The status review of the distribution tariff structures and the identification of best tariff practices will be subject to future ACER reports. Find below the main findings in different areas.\n\nMethodology setting\n\nIn all but three jurisdictions/countries the corresponding National Regulatory Authority (NRA) directly sets the transmission tariff methodology or approves a proposal by the transmission system operator. Tariff stability and predictability are pursued when setting transmission tariffs; in most jurisdictions countries, the tariff methodology is set for multiple years (frequently four or five).\n\nIn all but five countries a public consultation is carried out before the transmission tariff methodology is set, in others at least some key stakeholders are consulted. The information on fundamental tariff elements is usually publicly available.\n\nApplication of tariffs \u200b\n\nAbout half of the jurisdictions apply transmission tariffs for injection, beyond the transmission tariffs for withdrawal, which apply in all jurisdictions. The share of costs paid by producers ranges from around 2% up to 35%, depending on the jurisdiction. Full or partial exemptions from the transmission tariffs apply in a few jurisdictions to some network users such as small-capacity producers, energy storage facilities and lower-voltage level connected users.\n\nInjection charges have only an energy component in half of the jurisdictions, while in four jurisdictions an additional power-based or a lump sum component is also applied. Three jurisdictions have a capacity-based injection charge. The withdrawal charges mostly have an energy-based and a power-based component. Few jurisdictions apply a pure energy-based charge and one jurisdiction has a charge with a power based and a lump sum component.\n\nCosts categories can be recovered by a single transmission tariff or by a combination of different charges. ACER notes that this variety of tariff structures, including the different perimeters of the transmission tariff, makes the comparison of transmission tariffs in Europe a difficult task, where distinguishing at least between network tariffs and charges for system services would be helpful.\n\nEconomic signals embedded in tariffs\n\nIn about 40% of the jurisdictions time signals are embedded in transmission tariffs, mostly in the withdrawal charges. Several time signal types (seasonal, day and night, peak, dynamic pricing) often coexist. In about 20% of the jurisdictions locational signals are incorporated in transmission tariffs, frequently both in the injection charges and in the withdrawal charges.", 'processed_text': 'analysis national methodology electricity transmission tariff eu european union agency cooperation energy regulator released today report reviewing status methodology electricity transmission tariff european union member state report contribution towards clean energy package objective increase transparency comparability tariffsetting report also present finding acer monitoring transmission charge paid producer status review distribution tariff structure identification best tariff practice subject future report find main finding different area methodology setting three jurisdictionscountries corresponding national regulatory authority nra directly set trans ...

# %%
import json

with open(PREPROCESSED_JSON_FILE, 'wt') as out:
    json.dump(raw_data, out)
    assert os.path.exists(PREPROCESSED_JSON_FILE), "Json file must be created."

# %%
# !ls
# Out:
#  agency_counts.csv			 label_agency_heatmap.png
#  agency_label_crosstab.csv		 label_counts.csv
#  agency_label_crosstab_percentages.csv	 labels2.json
#  all_data.json				 labels.csv
#  all_data_no_predictions.csv		 labels.json
#  analyze.ipynb				 Machine_Learning.ipynb
# 'Coding for Hugo.xlsx'			 make_new_labels_file.ipynb
#  confidence_pivot.csv			 pycaret.ipynb
#  confidence_pivot_only_agencies.csv	 raw_data.json
#  confidence_pivot_only_labels.csv	 regulatory_vs_non_regulatory.csv
#  data_with_labels.csv			 regulatory_vs_non_regulatory.png
#  documents_txt				 results
#  dpc2vec.ipynb				 SVM_trained.pk
#  evaluation_pivot.csv			'Training Set for Hugo'
#  evaluation_pivot_only_agencies.csv	 vectorizer.pk
#  evaluation_pivot_only_labels.csv	 year_label_heatmap.png
#  experiments_results

# %% [markdown]
# ## Make DTM

# %%
import numpy as np
texts = []
y_1 = []
y_2 = []

for identifier, data_line in tqdm_notebook(raw_data.items()):
    texts.append(data_line.get('processed_text'))
    y_1.append(data_line.get("Dimension 1st"))
    y_2.append(data_line.get("Dimension 2nd"))

y_1 = np.array(y_1, dtype = np.int16)
y_2 = np.array(y_2, dtype = np.int16)
texts = np.array(texts)

y1_all = y_1


y_1
# Out:
# /home/hugo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/1302 [00:00<?, ?it/s]
# array([1, 1, 2, ..., 3, 1, 2], dtype=int16)

# %%
from collections import Counter

# %%
count = Counter(y_1)
count
# Out:
# Counter({1: 328, 2: 547, 3: 302, 4: 125})

# %%
np.array(list(count.values()))/sum(list(count.values()))
# Out:
# array([0.25192012, 0.42012289, 0.23195084, 0.09600614])

# %% [markdown]
# #### Shuffle

# %%
# np.random.seed(1)
# random_array = np.random.rand(len(texts))

# indices = np.argsort(random_array)

# texts_ = texts[indices]
# y_1 = y_1[indices]
# y_2 = y_2[indices]
# print(len(texts))

# %% [markdown]
# ### Separate Train-test

# %%
from sklearn.model_selection import train_test_split

texts_train, texts_test, y1_train, y1_test, y2_train, y2_test = train_test_split(texts, y_1, y_2, train_size=0.90, random_state=42)

assert len(texts_train) == len(y1_train) == len(y2_train)
assert len(texts_test) == len(y1_test) == len(y2_test)

# %%
y_1
# Out:
# array([1, 1, 2, ..., 3, 1, 2], dtype=int16)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(sublinear_tf = True)
X_train = vectorizer.fit_transform(texts_train)

print(X_train.shape)
# Out:
# (1171, 14744)

# %% [markdown]
# #### Store vectorizer

# %%
import pickle

with open('vectorizer.pk', 'wb') as fin:
    pickle.dump(vectorizer, fin)

# %%
ls
# Out:
#  agency_counts.csv                       label_agency_heatmap.png
#  agency_label_crosstab.csv               label_counts.csv
#  agency_label_crosstab_percentages.csv   labels2.json
#  all_data.json                           labels.csv
#  all_data_no_predictions.csv             labels.json
#  analyze.ipynb                           Machine_Learning.ipynb
# 'Coding for Hugo.xlsx'                   make_new_labels_file.ipynb
#  confidence_pivot.csv                    pycaret.ipynb
#  confidence_pivot_only_agencies.csv      raw_data.json
#  confidence_pivot_only_labels.csv        regulatory_vs_non_regulatory.csv
#  data_with_labels.csv                    regulatory_vs_non_regulatory.png
#  documents_txt/                          results/
#  dpc2vec.ipynb                           SVM_trained.pk
#  evaluation_pivot.csv                   'Training Set for Hugo'/
#  evaluation_pivot_only_agencies.csv      vectorizer.pk
#  evaluation_pivot_only_labels.csv        year_label_heatmap.png
#  experiments_results/

# %% [markdown]
# ## Test different models
#
# Experiments:
#
# * SVM 1st dim and SVM 2nd dim
# * randm forest 1st dim and 2nd dim
# * logreg 1st and 2nd
# * multilabel classification

# %%
display_cols_svm = ['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
       'param_C', 'param_kernel', 'params', 'mean_test_score', 'std_test_score', 'rank_test_score', 'mean_train_score', 'std_train_score']

results_folder = "experiments_results"

# %%
if not os.path.exists(results_folder):
    os.makedirs(results_folder)

# %%
def make_results_filename(classifier, dim, comment = ""):
    return f"{results_folder}/{classifier}_{dim}_{comment}.csv"

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

X_test = vectorizer.transform(texts_test)

def evaluate_on_test(X_train, X_test, y_train, y_test, best_params, algorithm):
    print(best_params)
    print("-"*80, end = '\n\n')
    
    final_model = algorithm(**best_params)
    final_model.fit(X= X_train, y = y_train)
    y_pred = final_model.predict(X_test)
    
    print(classification_report(y_test, y_pred))
    print("-"*80,end = '\n\n')
    print(confusion_matrix(y1_test, y_pred))

# %% [markdown]
# ### SVM

# %% [markdown]
# #### Define experiment

# %%
import pandas as pd 
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

def svc_experiment(X,y):
    svc = SVC()
    parameters = {'kernel':('linear', 'rbf'), 'C':[10, 100, 1000, 1e4, 1e5, 1e6]} #0.1, 1, 10,

    clf = GridSearchCV(svc, parameters, n_jobs=3, scoring='precision_weighted', cv=10, verbose=10, return_train_score=True)
    clf.fit(X, y)
    
    svm_results = clf.cv_results_
    
    return clf, svm_results

# %% [markdown]
# #### 1st dim

# %%
svm_y1_cv_model, svm_y1_results_json = svc_experiment(X= X_train, y = y1_train)

svm_y1_results = pd.DataFrame(svm_y1_results_json)
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=3)]: Done   7 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=3)]: Done  12 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=3)]: Done  19 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=3)]: Done  26 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=3)]: Done  55 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=3)]: Done  66 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=3)]: Done  79 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=3)]: Done  92 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=3)]: Done 107 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=3)]: Done 120 out of 120 | elapsed:  3.5min finished

# %%
svm_y1_results[display_cols_svm].sort_values(by="mean_test_score", ascending=False)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time    param_C  \
# 0        2.839311      0.272730         0.199871        0.025790         10
# 3        3.262792      0.458160         0.208619        0.041545        100
# 1        3.499767      0.546018         0.222708        0.056728         10
# 5        3.497172      0.472274         0.256351        0.076829       1000
# 7        2.842199      0.294361         0.203070        0.028338    10000.0
# 9        3.522713      0.479526         0.225861        0.058160   100000.0
# 11       2.934482      0.217782         0.203712        0.025514  1000000.0
# 2        3.735982      0.784109         0.257373        0.059612        100
# 4        2.650310      0.273862         0.180008        0.020459       1000
# 6        3.116816      0.685410         0.195604        0.035510    10000.0
# 8        2.877185      0.178530         0.198021        0.035355   100000.0
# 10       2.692070      0.362948         0.194930        0.033207  1000000.0
#
#    param_kernel                                params  mean_test_score  \
# 0        linear         {'C': 10, 'kernel': 'linear'}         0.712857
# 3           rbf           {'C': 100, 'kernel': 'rbf'}         0.709670
# 1           rbf            {'C': 10, 'kernel': 'rbf'}         0.709237
# 5           rbf          {'C': 1000, 'kernel': 'rbf'}         0.708740
# 7           rbf       {'C': 10000.0, 'kernel': 'rbf'}         0.708740
# 9           rbf      {'C': 100000.0, 'kernel': 'rbf'}         0.708740
# 11          rbf     {'C': 1000000.0, 'kernel': 'rbf'}         0.708740
# 2        linear        {'C': 100, 'kernel': 'linear'}         0.695526
# 4        linear       {'C': 1000, 'kernel': 'linear'}         0.680395
# 6        linear    {'C': 10000.0, 'kernel': 'linear'}         0.680395
# 8        linear   {'C': 100000.0, 'kernel': 'linear'}         0.680395
# 10       linear  {'C': 1000000.0, 'kernel': 'linear'}         0.680395
#
#     std_test_score  rank_test_score  mean_train_score  std_train_score
# 0         0.031661                1          0.994698         0.001213
# 3         0.038082                2          0.999337         0.000434
# 1         0.031450                3          0.997544         0.000463
# 5         0.039833                4          1.000000         0.000000
# 7         0.039833                4          1.000000         0.000000
# 9         0.039833                4          1.000000         0.000000
# 11        0.039833                4          1.000000         0.000000
# 2         0.030588                8          0.999243         0.000379
# 4         0.019466                9          1.000000         0.000000
# 6         0.019466                9          1.000000         0.000000
# 8         0.019466                9          1.000000         0.000000
# 10        0.019466                9          1.000000         0.000000

# %%
outfile = make_results_filename('svm', 1)
print(outfile)

svm_y1_results.to_csv(outfile, sep='\t')

# !ls experiments_results
# Out:
# experiments_results/svm_1_.csv
# LR_1_.csv  LR_2_.csv  RF_1_.csv  RF_2_.csv  svm_1_.csv	svm_2_.csv

# %%
svm_y1_cv_model.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
# X_test = vectorizer.transform(texts_test)

# cv_model.best_params_

# final_model = SVC(C = cv_model.best_params_['C'], kernel = cv_model.best_params_['kernel'])
# final_model.fit(X= X_train, y = y1_train)
# y1_pred = final_model.predict(X_test)

# %%
# from sklearn.metrics import classification_report
# print(classification_report(y1_test, y1_pred))

# %%
# from sklearn.metrics import confusion_matrix
# confusion_matrix(y1_test, y1_pred)

# %%
# from sklearn.metrics import classification_report
# from sklearn.metrics import confusion_matrix

# def evaluate_on_test(X_train, X_test, y_train, y_test, best_params):
#     print(best_params)
#     print("-"*80, end = '\n\n')
    
#     final_model = SVC(**best_params)
#     final_model.fit(X= X_train, y = y_train)
#     y_pred = final_model.predict(X_test)
    
#     print(classification_report(y_test, y_pred))
#     print("-"*80,end = '\n\n')
#     print(confusion_matrix(y1_test, y1_pred))

# %%
evaluate_on_test(X_train, X_test, y1_train, y1_test, svm_y1_cv_model.best_params_, algorithm=SVC)
# Out:
# {'C': 10, 'kernel': 'linear'}
# --------------------------------------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            1       0.78      0.85      0.82        34
#            2       0.70      0.81      0.75        52
#            3       0.81      0.60      0.69        35
#            4       0.62      0.50      0.56        10
#
#     accuracy                           0.74       131
#    macro avg       0.73      0.69      0.70       131
# weighted avg       0.74      0.74      0.74       131
#
# --------------------------------------------------------------------------------
#
# [[29  3  1  1]
#  [ 5 42  4  1]
#  [ 2 11 21  1]
#  [ 1  4  0  5]]

# %% [markdown]
# ### Train and store the svm

# %%
X_all = vectorizer.transform(texts)
X_all.shape
# Out:
# (1302, 14744)

# %%
y1_all.shape
# Out:
# (1302,)

# %%
from sklearn.svm import SVC

svc = SVC(probability=True, **svm_y1_cv_model.best_params_)
svc.fit(X_all, y1_all)
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
import pickle
with open("SVM_trained.pk", "wb") as out:
    pickle.dump(svc, out)

# %%
ls
# Out:
#  agency_counts.csv                       label_agency_heatmap.png
#  agency_label_crosstab.csv               label_counts.csv
#  agency_label_crosstab_percentages.csv   labels2.json
#  all_data.json                           labels.csv
#  all_data_no_predictions.csv             labels.json
#  analyze.ipynb                           Machine_Learning.ipynb
# 'Coding for Hugo.xlsx'                   make_new_labels_file.ipynb
#  confidence_pivot.csv                    pycaret.ipynb
#  confidence_pivot_only_agencies.csv      raw_data.json
#  confidence_pivot_only_labels.csv        regulatory_vs_non_regulatory.csv
#  data_with_labels.csv                    regulatory_vs_non_regulatory.png
#  documents_txt/                          results/
#  dpc2vec.ipynb                           SVM_trained.pk
#  evaluation_pivot.csv                   'Training Set for Hugo'/
#  evaluation_pivot_only_agencies.csv      vectorizer.pk
#  evaluation_pivot_only_labels.csv        year_label_heatmap.png
#  experiments_results/

# %% [markdown]
# #### 2nd dim

# %%
svm_y2_cv_model, svm_y2_results_json = svc_experiment(X_train, y2_train)
svm_y2_results = pd.DataFrame(svm_y2_results_json)
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=3)]: Done   7 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=3)]: Done  12 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=3)]: Done  19 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=3)]: Done  26 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=3)]: Done  55 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=3)]: Done  66 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=3)]: Done  79 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=3)]: Done  92 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=3)]: Done 107 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=3)]: Done 120 out of 120 | elapsed:  3.2min finished

# %%
svm_y2_results[display_cols_svm]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time    param_C  \
# 0        3.172088      0.553313         0.234160        0.064028         10
# 1        2.817281      0.244723         0.192199        0.028273         10
# 2        2.757764      0.275318         0.189058        0.031316        100
# 3        2.817969      0.381386         0.197623        0.029578        100
# 4        2.876647      0.296298         0.202788        0.065638       1000
# 5        2.845318      0.276846         0.198888        0.033195       1000
# 6        2.626746      0.331761         0.188646        0.020888    10000.0
# 7        2.786863      0.356504         0.193177        0.031858    10000.0
# 8        2.738735      0.335278         0.185713        0.018529   100000.0
# 9        2.765023      0.324701         0.200275        0.037087   100000.0
# 10       2.697953      0.259339         0.187313        0.022340  1000000.0
# 11       2.800266      0.329143         0.199119        0.026003  1000000.0
#
#    param_kernel                                params  mean_test_score  \
# 0        linear         {'C': 10, 'kernel': 'linear'}         0.462075
# 1           rbf            {'C': 10, 'kernel': 'rbf'}         0.491324
# 2        linear        {'C': 100, 'kernel': 'linear'}         0.456692
# 3           rbf           {'C': 100, 'kernel': 'rbf'}         0.481956
# 4        linear       {'C': 1000, 'kernel': 'linear'}         0.447109
# 5           rbf          {'C': 1000, 'kernel': 'rbf'}         0.481255
# 6        linear    {'C': 10000.0, 'kernel': 'linear'}         0.447109
# 7           rbf       {'C': 10000.0, 'kernel': 'rbf'}         0.481255
# 8        linear   {'C': 100000.0, 'kernel': 'linear'}         0.447109
# 9           rbf      {'C': 100000.0, 'kernel': 'rbf'}         0.481255
# 10       linear  {'C': 1000000.0, 'kernel': 'linear'}         0.447109
# 11          rbf     {'C': 1000000.0, 'kernel': 'rbf'}         0.481255
#
#     std_test_score  rank_test_score  mean_train_score  std_train_score
# 0         0.032599                7          0.990263         0.001338
# 1         0.042698                1          0.996025         0.001018
# 2         0.031812                8          0.997916         0.000569
# 3         0.044471                2          0.999243         0.000378
# 4         0.034886                9          1.000000         0.000000
# 5         0.042433                3          1.000000         0.000000
# 6         0.034886                9          1.000000         0.000000
# 7         0.042433                3          1.000000         0.000000
# 8         0.034886                9          1.000000         0.000000
# 9         0.042433                3          1.000000         0.000000
# 10        0.034886                9          1.000000         0.000000
# 11        0.042433                3          1.000000         0.000000

# %%
outfile = make_results_filename('svm', 2)
print(outfile)

svm_y2_results.to_csv(outfile, sep='\t')

# !ls experiments_results
# Out:
# experiments_results/svm_2_.csv
# LR_1_.csv  LR_2_.csv  RF_1_.csv  RF_2_.csv  svm_1_.csv	svm_2_.csv

# %%
evaluate_on_test(X_train, X_test, y2_train, y2_test, svm_y2_cv_model.best_params_, algorithm=SVC)
# Out:
# {'C': 10, 'kernel': 'rbf'}
# --------------------------------------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            1       0.50      0.50      0.50        28
#            2       0.42      0.57      0.48        44
#            3       0.64      0.64      0.64        42
#            4       0.00      0.00      0.00        17
#
#     accuracy                           0.50       131
#    macro avg       0.39      0.43      0.41       131
# weighted avg       0.45      0.50      0.47       131
#
# --------------------------------------------------------------------------------
#
# [[22  8  4  0]
#  [ 2 32 18  0]
#  [ 3 12 20  0]
#  [ 1  8  0  1]]

# %% [markdown]
# ### Random Forest

# %%
display_cols_RF = ['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
       'param_n_estimators', 'param_max_depth', 'params', 'mean_test_score', 'std_test_score', 'rank_test_score', 'mean_train_score', 'std_train_score']

# %% [markdown]
# #### Define Experiment

# %%
from sklearn.ensemble import RandomForestClassifier

def RF_experiment(X,y):
    rf = RandomForestClassifier()
    parameters = {'n_estimators':[10,20,50, 100, 120, 150, 200, 250, 300, 1000], 'max_depth': [10, 20, 50, None]}

    clf = GridSearchCV(rf, parameters, n_jobs=3, scoring='f1_weighted', cv=10, verbose=10, return_train_score=True)
    clf.fit(X, y)
    
    svm_results = pd.DataFrame(clf.cv_results_)
    
    return clf, svm_results

# %% [markdown]
# #### 1st dim

# %%
RF_y1_cv_model, RF_y1_results = RF_experiment(X_train, y1_train)
# Out:
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Batch computation too fast (0.1099s.) Setting batch_size=2.
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done   8 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=3)]: Done  18 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=3)]: Done  32 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=3)]: Batch computation too slow (2.2564s.) Setting batch_size=1.
# [Parallel(n_jobs=3)]: Done  46 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=3)]: Done  59 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=3)]: Done  68 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=3)]: Done  79 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=3)]: Done  90 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=3)]: Done 103 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=3)]: Done 116 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=3)]: Done 131 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=3)]: Done 146 tasks      | elapsed:   59.9s
# [Parallel(n_jobs=3)]: Done 163 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=3)]: Done 180 tasks      | elapsed:  1.4min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-44f6f289951b> in <module>
# ----> 1 RF_y1_cv_model, RF_y1_results = RF_experiment(X_train, y1_train)
#
# <ipython-input-60-a52d3f67ef47> in RF_experiment(X, y)
#       6
#       7     clf = GridSearchCV(rf, parameters, n_jobs=3, scoring='f1_weighted', cv=10, verbose=10, return_train_score=True)
# ----> 8     clf.fit(X, y)
#       9
#      10     svm_results = pd.DataFrame(clf.cv_results_)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
RF_y1_results[display_cols_RF]

# %%
outfile = make_results_filename('RF', 1)
print(outfile)

RF_y1_results.to_csv(outfile, sep='\t')

# !ls experiments_results

# %%
RF_y1_cv_model.best_params_

# %%
evaluate_on_test(X_train, X_test, y1_train, y1_test, RF_y1_cv_model.best_params_, algorithm=RandomForestClassifier)

# %%
# RF_y1_cv_model.best_params_

# %%
# X_test = vectorizer.transform(texts_test)

# RF_y1_cv_model.best_params_

# RF_y1_final_model = RandomForestClassifier(
#     max_depth = RF_y1_cv_model.best_params_['max_depth'], 
#     n_estimators = RF_y1_cv_model.best_params_['n_estimators'])

# RF_y1_final_model.fit(X= X_train, y = y1_train)
# RF_y1_pred = RF_y1_final_model.predict(X_test)

# %%
# from sklearn.metrics import classification_report
# print(classification_report(y1_test, RF_y1_pred))

# %%
# from sklearn.metrics import confusion_matrix
# confusion_matrix(y1_test, RF_y1_pred)

# %% [markdown]
# #### 2nd dim

# %%
RF_y2_cv_model, RF_y2_results = RF_experiment(X_train, y2_train)

# %%
RF_y2_results[display_cols_RF]

# %%
outfile = make_results_filename('RF', 2)
print(outfile)

RF_y2_results.to_csv(outfile, sep='\t')

# !ls experiments_results

# %%
RF_y1_cv_model.best_params_

# %%
evaluate_on_test(
    X_train, 
    X_test, 
    y2_train, 
    y2_test, 
    RF_y2_cv_model.best_params_,
    algorithm= RandomForestClassifier)

# %%
# X_test = vectorizer.transform(texts_test)

# RF_y2_cv_model.best_params_

# RF_y2_final_model = RandomForestClassifier(
#     max_depth = RF_y2_cv_model.best_params_['max_depth'], 
#     n_estimators = RF_y2_cv_model.best_params_['n_estimators'])

# RF_y2_final_model.fit(X= X_train, y = y2_train)
# RF_y2_pred = RF_y2_final_model.predict(X_test)

# %%
# from sklearn.metrics import classification_report
# print(classification_report(y2_test, RF_y2_pred))

# %%
# from sklearn.metrics import confusion_matrix
# confusion_matrix(y2_test, RF_y2_pred)

# %% [markdown]
# ### Logistic Regression

# %%
display_cols_LR = ['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
       'param_penalty', 'param_C', 'params', 'mean_test_score', 'std_test_score', 'rank_test_score', 'mean_train_score', 'std_train_score']

# %% [markdown]
# #### Define Experiment

# %%
from sklearn.linear_model import LogisticRegression

def RF_experiment(X,y):
    lr = LogisticRegression()
    parameters = {'penalty':['l1', 'l2'], 'C':[0.1, 1, 10, 20, 100, 200, 1000, 2000, 1e4, 1e5]}

    clf = GridSearchCV(lr, parameters, n_jobs=3, scoring='f1_weighted', cv=10, verbose=10, return_train_score=True)
    clf.fit(X, y)
    
    svm_results = pd.DataFrame(clf.cv_results_)
    
    return clf, svm_results

# %% [markdown]
# #### 1st dim

# %%
LR_y1_cv_model, LR_y1_results = RF_experiment(X_train, y1_train)

# %%
LR_y1_results[display_cols_LR]

# %%
outfile = make_results_filename('LR', 1)
print(outfile)

LR_y1_results.to_csv(outfile, sep='\t')

# !ls experiments_results

# %%
evaluate_on_test(
    X_train, 
    X_test, 
    y1_train, 
    y1_test, 
    LR_y1_cv_model.best_params_,
    algorithm= LogisticRegression)

# %%
# X_test = vectorizer.transform(texts_test)

# LR_cv_model.best_params_

# final_model = LR(C = cv_model.best_params_['C'], kernel = cv_model.best_params_['kernel'])
# final_model.fit(X= X_train, y = y1_train)
# y1_pred = final_model.predict(X_test)

# %% [markdown]
# #### 2nd dim

# %%
LR_y2_cv_model, LR_y2_results = RF_experiment(X_train, y2_train)

# %%
LR_y2_results[display_cols_LR]

# %%
outfile = make_results_filename('LR', 2)
print(outfile)

LR_y1_results.to_csv(outfile, sep='\t')

# !ls experiments_results

# %%
evaluate_on_test(
    X_train, 
    X_test, 
    y2_train, 
    y2_test, 
    LR_y2_cv_model.best_params_,
    algorithm= LogisticRegression)

# %% [markdown]
# ## Label analysis
#
# In this section I will explore how often a model trained on the first demention predicts a label from the second demention. But first I will explore if labels "correlate".

# %%
y_1

# %%
y_2

# %%
from collections import Counter

# %%
Counter(y_1)

# %%
Counter(y_2)

# %%
conf_matrix = np.zeros((4,4), dtype = np.int16)
conf_matrix

# %%
for first, second in zip(y_1, y_2):
    conf_matrix[first-1, second-1] += 1
    
conf_matrix

# %%
from collections import defaultdict

d = defaultdict(lambda :0)

for first, second in zip(y_1, y_2):
    d[f"{first}_{second}"] += 1


sorted(d.items(), key=lambda x:x[0])

# %% [markdown]
# ### Analyze different classifiers

# %% [markdown]
# First write the evaluation function

# %%
from collections import defaultdict


def evaluate_together(y_1_true, y_2_true, y_1_pred):
    assert len(y_1_true) == len(y_2_true) == len(y_1_pred)
#     results = defaultdict(lambda :defaultdict(lambda : ))
    results = {
        "first_degree": 0,
        "second_degree": 0,
        "false": 0
    }
    total = 0
    for true_1, true_2, pred in zip(y_1_true, y_2_true, y_1_pred):
        if pred == true_1:
            results["first_degree"] += 1
        elif pred == true_2:
            results["second_degree"] += 1
        else:
            results["false"] += 1
            
        total += 1
        
    assert total == len(y_1_true) == len(y_2_true) == len(y_1_pred) == total
    
    return results, total
    
def return_defdict():
    return defaultdict(int)
    
def evaluate_together2(y_1_true, y_2_true, y_1_pred):
    assert len(y_1_true) == len(y_2_true) == len(y_1_pred)
    results = defaultdict(return_defdict)
#     results = {
#         "first_degree": 0,
#         "second_degree": 0,
#         "false": 0
#     }
    total = 0
    for true_1, true_2, pred in zip(y_1_true, y_2_true, y_1_pred):
        if pred == true_1:
            results[true_1]["first_degree"] += 1
        elif pred == true_2:
            results[true_1]["second_degree"] += 1
        else:
            results[true_1]["false"] += 1
            
        total += 1
        
    assert total == len(y_1_true) == len(y_2_true) == len(y_1_pred) == total
    
    return results, total

# %% [markdown]
# #### SVM

# %%
Counter(y1_test)

# %%
svc = SVC(**svm_y1_cv_model.best_params_)
svc.fit(X_train, y1_train)

y_pred = svc.predict(X_test)

results, total = evaluate_together(y1_test, y2_test, y_pred)
print(results)
print('2nd degree accuracy:\t', (results['first_degree'] + results['second_degree'])/total)

# %%
results2, total2 = evaluate_together2(y1_test, y2_test, y_pred)
results2

# %%
for label, res in sorted(results2.items(), key= lambda x:x[0]):
    fd = res.get('first_degree',0)
    sd = res.get('second_degree', 0)
    errors = res.get('false',0)
    
#     print(fd,sd,errors)
    first_degree_precision = fd / (fd+sd+errors)
    second_degree_precision = (fd + sd)/ (fd + sd + errors)
    print("-",label)
    print('\tfirst degree:\t', first_degree_precision)
    print('\tsecond degree:\t', second_degree_precision)
#     print(label, res)

# %% [markdown]
# #### RF

# %%
rf = RandomForestClassifier(**RF_y1_cv_model.best_params_)
rf.fit(X_train, y1_train)

y_pred = rf.predict(X_test)

results, total = evaluate_together(y1_test, y2_test, y_pred)
print(results)
print('2md degree accuracy:\t', (results['first_degree'] + results['second_degree'])/total)

print('-'*50)

results2, total2 = evaluate_together2(y1_test, y2_test, y_pred)
print(results2)

# %% [markdown]
# ## SMOTE

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

X_test = vectorizer.transform(texts_test)

def evaluate_on_test_SMOTE(X_train, X_test, y_train, y_test, best_params, algorithm):
    sm = SMOTE(random_state=42)
    X_res, y_res = sm.fit_resample(X_train, y_train)
    print(best_params)
    print("-"*80, end = '\n\n')
    
    final_model = algorithm(**best_params)
    final_model.fit(X= X_res, y = y_res)
    y_pred = final_model.predict(X_test)
    
    print(classification_report(y_test, y_pred))
    print("-"*80,end = '\n\n')
    print(confusion_matrix(y1_test, y_pred))

# %%
# grid = GridSearchCV(model, params, ...)
# grid.fit(X, y)

# %%
import pandas as pd 
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE 
from imblearn.pipeline import Pipeline


def svc_SMOTE_experiment(X,y):
        
    sm = SMOTE(random_state=42)
    X_res, y_res = sm.fit_resample(X, y)
    
    model = Pipeline([
        ('sampling', SMOTE()),
        ('classification', SVC())
    ])
    

    parameters = {'classification__kernel':('linear', 'rbf'), 'classification__C':[100, 1000, 1e4, 1e5, 1e6]} #0.1, 1, 10,
    
    clf = GridSearchCV(model, parameters, n_jobs=3, scoring='f1_weighted', cv=10, verbose=10, return_train_score=True)
    clf.fit(X_res, y_res)
    
    svm_results = clf.cv_results_
    
    return clf, svm_results

# %%
svm_y1_cv_model, svm_y1_results_json = svc_SMOTE_experiment(X= X_train, y = y1_train)

svm_y1_results = pd.DataFrame(svm_y1_results_json)

# %%
outfile = make_results_filename('svm', 1)
print(outfile)

svm_y1_results.to_csv(outfile, sep='\t')

# %%
svm_y1_results

# %%
evaluate_on_test_SMOTE(X_train, X_test, y1_train, y1_test, svm_y1_cv_model.best_params_, algorithm=SVC)

# %% [markdown]
# ## Doc2Vec

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from gensim.models import Doc2Vec
from sklearn import utils
from sklearn.model_selection import train_test_split
import gensim
from sklearn.linear_model import LogisticRegression
from gensim.models.doc2vec import TaggedDocument
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_tagged = [TaggedDocument(text,[label]) for text, label in zip(texts_train, y1_train)]
# train.apply(
#     lambda r: TaggedDocument(words=tokenize_text(r['narrative']), tags=[r.Product]), axis=1)
test_tagged = [TaggedDocument(text,[label]) for text, label in zip(texts_test, y1_test)]
#                 test.apply(
#     lambda r: TaggedDocument(words=tokenize_text(r['narrative']), tags=[r.Product]), axis=1)

# %%
import multiprocessing

cores = multiprocessing.cpu_count() -1

# %%
model_dbow = Doc2Vec(dm=0, vector_size=100, negative=5, hs=0, min_count=2, sample = 0, workers=cores)

# %%
model_dbow.build_vocab([x for x in tqdm_notebook(train_tagged)])

# %%
for epoch in range(30):
    model_dbow.train(utils.shuffle([x for x in tqdm(train_tagged)]), total_examples=len(train_tagged), epochs=1)
    model_dbow.alpha -= 0.002
    model_dbow.min_alpha = model_dbow.alpha

# %% [markdown]
# ## Multilabel Classification
